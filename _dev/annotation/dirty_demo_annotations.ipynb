# %% [markdown]
# # Dirty Demo Annotations
#
# Requested to make a more stylish frame for the stroker demo.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import necessary libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt
from dirty_demo_annotations import add_all_annotations
# Create a blank image dimensions of phone screen (portrait)
image = np.zeros((1080, 1920, 3), dtype=np.uint8)

# Add all annotations
image = add_all_annotations(image)

# Convert the image from BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image in the notebook
plt.imshow(image_rgb)
plt.axis('on')  # Hide the axis
plt.show()
